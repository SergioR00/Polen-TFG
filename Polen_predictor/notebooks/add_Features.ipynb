# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ### Adding Biological features (last year)

# %%
def add_biological_features(file_path):
    df = pd.read_csv(file_path)
    df['fecha'] = pd.to_datetime(df['fecha'])

    cols_memoria = [
        'precip_autumn_last_year', 'precip_winter_last_year',
        'temp_mean_spring_summer_last', 'humidity_sum_spring_summer_last',
        'co2_mean_april_may_last', 'o3_mean_april_may_last',
        'no2_mean_april_may_last', 'drought_days_summer_last',
        'growing_degree_days_last'
    ]
    df = df.drop(columns=[c for c in cols_memoria if c in df.columns], errors='ignore')

    years = df['fecha'].dt.year.unique()
    memory_features = []
        
    for year in years:
        mask_year = df['fecha'].dt.year == year
        df_year = df[mask_year].copy()
        if len(df_year) < 260: 
            continue

        mask_am = df_year['fecha'].dt.month.isin([4, 5])
        mask_ma = df_year['fecha'].dt.month.isin([3, 4, 5, 6, 7, 8])
        mask_summer = df_year['fecha'].dt.month.isin([6, 7, 8])
        mask_autumn = df_year['fecha'].dt.month.isin([10, 11, 12])
        mask_winter = df_year['fecha'].dt.month.isin([1, 2, 3])

        precip_autumn = df_year.loc[mask_autumn, 'total_rain'].sum()
        precip_winter = df_year.loc[mask_winter, 'total_rain'].sum()
        temp_mean_ss = df_year.loc[mask_ma, 'temp_mean'].mean()
        humidity_sum_ss = df_year.loc[mask_ma, 'relative_humidity_2m (%)'].sum()
        co2_mean_am = df_year.loc[mask_am, 'CO (mg/m3)'].mean()
        o3_mean_am = df_year.loc[mask_am, 'O3 (ug/m3)'].mean()
        no2_mean_am = df_year.loc[mask_am, 'NO2 (ug/m3)'].mean()
        drought_days = (df_year.loc[mask_summer, 'total_rain'] < 1.0).sum()
        mask_gdd = (df_year['fecha'].dt.month >= 2)
        gdd = (df_year.loc[mask_gdd, 'temp_mean'] - 5).clip(lower=0).sum()

        memory_features.append({
            'year_target': year + 1,
            'precip_autumn_last_year': precip_autumn,
            'precip_winter_last_year': precip_winter,
            'temp_mean_spring_summer_last': temp_mean_ss,
            'humidity_sum_spring_summer_last': humidity_sum_ss,
            'co2_mean_april_may_last': co2_mean_am,
            'o3_mean_april_may_last': o3_mean_am,
            'no2_mean_april_may_last': no2_mean_am,
            'drought_days_summer_last': drought_days,
            'growing_degree_days_last': gdd
        })
        
    df_memory = pd.DataFrame(memory_features)
    df['year'] = df['fecha'].dt.year
    df = pd.merge(df, df_memory, left_on='year', right_on='year_target', how='left')
    df.drop(columns=['year_target', 'year'], inplace=True)
    df.to_csv(file_path, index=False)

# %% [markdown]
# ### Polen

# %%
def add_polen_features(file_path, tipo):
    df = pd.read_csv(file_path)
    df['fecha'] = pd.to_datetime(df['fecha'])

    lags_seleccionados = [1, 2, 3, 7, 14]

    df['polen_rolling_mean_3d'] = df[f'polen_{tipo}'].shift(1).rolling(window=3).mean()
    df['polen_rolling_mean_7d'] = df[f'polen_{tipo}'].shift(1).rolling(window=7).mean()

    for i in lags_seleccionados:
        df[f'polen_lag_{i}'] = df[f'polen_{tipo}'].shift(i)
        df[f'polen_rolling_mean_3d_lag_{i}'] = df['polen_rolling_mean_3d'].shift(i)
        df[f'polen_rolling_mean_7d_lag_{i}'] = df['polen_rolling_mean_7d'].shift(i)

    df['polen_trend_3d'] = df['polen_lag_1'] - df['polen_lag_3']
    df['polen_accel'] = (df['polen_lag_1'] - df['polen_lag_2']) - (df['polen_lag_2'] - df['polen_lag_3'])

    df.to_csv(file_path, index=False)

# %% [markdown]
# ### Lag Contaminantes y Meteo (1,2,3,4,7,14 días)

# %%
cols = [
    'NO2 (ug/m3)', 'O3 (ug/m3)', 'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'CO (mg/m3)', 'SO2 (ug/m3)',
    'Benceno (ug/m3)', 'Tolueno (ug/m3)', 'NO (ug/m3)', 'NOx (ug/m3)',
    "wind_speed_10m (km/h)",
    "wind_gusts_10m (km/h)",
    "relative_humidity_2m (%)",
    "dew_point_2m (°C)",
    "vapour_pressure_deficit (kPa)",
    "cloud_cover (%)",
    "soil_temperature_0_to_7cm (°C)",
    "soil_moisture_0_to_7cm (m³/m³)",
    "temp_mean",
    "wind_dir_dominant",
    "evapotranspiration",
    "radiation_sum",
    "max_temp",
    "min_temp",
    "total_rain"
]

def add_lags(file_path):
    df = pd.read_csv(file_path)
    df['fecha'] = pd.to_datetime(df['fecha'])
    for col in cols:
        if col in df.columns:
            for i in range(1, 4):
                df[f'{col}_lag_{i}'] = df[col].shift(i)
            df[f'{col}_lag_{7}'] = df[col].shift(7)
            df[f'{col}_lag_{14}'] = df[col].shift(14)
    df.to_csv(file_path, index=False)

# %% [markdown]
# ### Pred contaminantes y meteo (1,2,3 días)

# %%
cols = [
    'NO2 (ug/m3)', 'O3 (ug/m3)', 'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'CO (mg/m3)', 'SO2 (ug/m3)',
    'Benceno (ug/m3)', 'Tolueno (ug/m3)', 'NO (ug/m3)', 'NOx (ug/m3)',
    "wind_speed_10m (km/h)",
    "wind_gusts_10m (km/h)",
    "relative_humidity_2m (%)",
    "dew_point_2m (°C)",
    "vapour_pressure_deficit (kPa)",
    "cloud_cover (%)",
    "soil_temperature_0_to_7cm (°C)",
    "soil_moisture_0_to_7cm (m³/m³)",
    "temp_mean",
    "wind_dir_dominant",
    "evapotranspiration",
    "radiation_sum",
    "max_temp",
    "min_temp",
    "total_rain"
]

def add_preds(file_path):
    df = pd.read_csv(file_path)
    df['fecha'] = pd.to_datetime(df['fecha'])
    for col in cols:
        if col in df.columns:
            for i in range(1, 3):
                df[f'{col}_lag_{i}'] = df[col].shift(-i)
    df.to_csv(file_path, index=False)

# %% [markdown]
# ### Others

# %%
def add_other_features(file_path):
    df = pd.read_csv(file_path)
    df['fecha'] = pd.to_datetime(df['fecha'])
    df['temp_diff_3d'] = df['temp_mean'] - df['temp_mean'].shift(3)
    df['humidity_drop_2d'] = df['relative_humidity_2m (%)'] - df['relative_humidity_2m (%)'].shift(2)
    df['viento_x_temperatura'] = df['wind_speed_10m (km/h)'] * df['temp_mean']

    df['polen_stress_index'] = df['max_temp'] / (df['relative_humidity_2m (%)'] + 1)
    df['rain_cleaning_index'] = df['polen_lag_1'] / (df['total_rain'] + 1)
    df['polen_transport_potential'] = df['polen_lag_1'] * df['wind_gusts_10m (km/h)']
    df['hydric_stress_index_cup'] = df['relative_humidity_2m (%)'].shift(1) - df['relative_humidity_2m (%)']
    df['hydric_stress_index_oli'] = df['vapour_pressure_deficit (kPa)'] / (df['soil_moisture_0_to_7cm (m³/m³)'] + 1e-6)
    df['thermal_hydric_ratio'] = df['temp_mean'] / (df['soil_moisture_0_to_7cm (m³/m³)'] + 1e-6)
    
    df['nitration_index'] = np.log1p(df['NO2 (ug/m3)'] * df['relative_humidity_2m (%)'])
    df['toxic_load'] = df['Benceno (ug/m3)'] + df['Tolueno (ug/m3)'] + df['NOx (ug/m3)']
    df['rupture_risk'] = (df['relative_humidity_2m (%)'] > 80).astype(int) * df['PM2.5 (ug/m3)']
    df['smog_index'] = df['O3 (ug/m3)'] * df['max_temp']

    df['defici_pression_vap_mean_3d'] = df['vapour_pressure_deficit (kPa)'].rolling(window=3).mean()
    df['day_of_year'] = df['fecha'].dt.dayofyear
    df['day_of_year_sin'] = np.sin(2 * np.pi * df['day_of_year'] / 365.25)
    df['day_of_year_cos'] = np.cos(2 * np.pi * df['day_of_year'] / 365.25)

    df.to_csv(file_path, index=False)

# %% [markdown]
# ### Adding features to each df

# %%
tipos_polinicos = ["gramineas", "cupresaceas", "olivo", "platano", "urticaceas", "quenopodiaceas"]

for tipo in tipos_polinicos:
    add_biological_features(rf"..\my_datasets\datos_{tipo}.csv")
    add_polen_features(rf"..\my_datasets\datos_{tipo}.csv", tipo)
    add_lags(rf"..\my_datasets\datos_{tipo}.csv")
    add_preds(rf"..\my_datasets\datos_{tipo}.csv")
    add_other_features(rf"..\my_datasets\datos_{tipo}.csv")
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{i}'] = df[col].shift(i)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{7}'] = df[col].shift(7)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_13716\1679809656.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_lag_{14}'] = df[col].shift(14)

# %% [markdown]
# ### Write Features

# %%
FEATURES = []
FEATURES += [
    "wind_speed_10m (km/h)",
    "wind_gusts_10m (km/h)",
    "relative_humidity_2m (%)",
    "dew_point_2m (°C)",
    "vapour_pressure_deficit (kPa)",
    "cloud_cover (%)",
    "soil_temperature_0_to_7cm (°C)",
    "soil_moisture_0_to_7cm (m³/m³)",
    "temp_mean",
    "wind_dir_dominant",
    "evapotranspiration",
    "radiation_sum",
    "max_temp",
    "min_temp",
    "total_rain"
]
FEATURES += [
    'NO2 (ug/m3)', 'O3 (ug/m3)', 'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'CO (mg/m3)', 'SO2 (ug/m3)',
    'Benceno (ug/m3)', 'Tolueno (ug/m3)', 'NO (ug/m3)', 'NOx (ug/m3)s'
]

for col in FEATURES.copy():
    for i in [1, 2, 3, 7, 14]:
        FEATURES.append(f'{col}_lag_{i}')

FEATURES += [
    'precip_autumn_last_year', 'precip_winter_last_year',
    'temp_mean_spring_summer_last', 'humidity_sum_spring_summer_last',
    'co2_mean_april_may_last', 'o3_mean_april_may_last', 
    'no2_mean_april_may_last', 'drought_days_summer_last', 
    'growing_degree_days_last'
]

FEATURES += ['polen_rolling_mean_3d', 'polen_rolling_mean_7d', 'polen_trend_3d', 'polen_accel']

for i in [1, 2, 3, 7, 14]:
    FEATURES.append(f'polen_lag_{i}')
    FEATURES.append(f'polen_rolling_mean_3d_lag_{i}')
    FEATURES.append(f'polen_rolling_mean_7d_lag_{i}')

FEATURES += ['temp_diff_3d', 'humidity_drop_2d', 'viento_x_temperatura', 'polen_stress_index', 'rain_cleaning_index', 'polen_transport_potential', 'hydric_stress_index_cup', 
            'hydric_stress_index_oli', 'thermal_hydric_ratio', 'defici_pression_vap_mean_3d', 'day_of_year', 'day_of_year_sin', 'day_of_year_cos',
            'nitration_index', 'toxic_load', 'rupture_risk', 'smog_index']

with open('json/allFeatures.json', 'w', encoding='utf-8') as f:
    json.dump(FEATURES, f, ensure_ascii=False, indent=4)

# Lluvia media 30 o 60 dias
