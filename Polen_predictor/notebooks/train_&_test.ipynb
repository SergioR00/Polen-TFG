# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import json
from datetime import date
import os

import seaborn as sns

color_pal = sns.color_palette()

plt.style.use("fivethirtyeight")
plt.rcParams["lines.linewidth"] = 1.5
plt.rcParams["lines.markersize"] = 4
plt.rcParams["font.size"] = 10
plt.rcParams["axes.titlesize"] = 14

# %%
def calculate_weights(
    target_y, features_X, base_high_w=10.0, alert_w=50.0, spike_w=200.0
):
    weights = np.ones(len(target_y))
    pollen = target_y.values

    # Tier 1: Low-Medium Levels (>= 10)
    weights[pollen >= 10] = base_high_w

    # Tier 2: Warnings/Alerts (>= 50)
    weights[pollen >= 50] = alert_w

    # Tier 3: "Explosive Spike" (Jump >= 300)
    if "polen_lag_1" in features_X.columns:
        pollen_today = pollen
        pollen_yesterday = features_X["polen_lag_1"].values
        try:
            jump = pollen_today - pollen_yesterday
            explosive_mask = jump >= 300
            weights[explosive_mask] = spike_w
        except:
            pass
    
    weights = np.power(1.5, np.log1p(target_y))
    return weights

# %%
def apply_safety_noise(X, tipo, seed=None):
    X_noisy = X.copy()

    NOISE_LEVEL = 0.20
    SAFETY_BIAS = 0.90

    if f"polen_{tipo}" in X_noisy.columns:
        noise = np.random.normal(SAFETY_BIAS, NOISE_LEVEL, size=len(X_noisy))
        X_noisy[f"polen_{tipo}"] = (
            X_noisy[f"polen_{tipo}"] * noise
        )

    return X_noisy

# %%
# Creación de los targets
def create_targets(df, tipo):
    df[f"target_t0"] = df[f"polen_{tipo}"]
    df[f"target_t1"] = df[f"polen_{tipo}"].shift(-1)
    df[f"target_t2"] = df[f"polen_{tipo}"].shift(-2)

# %% [markdown]
# ### Train final models

# %%
tipos_polinicos = ["gramineas", "cupresaceas", "olivo", "platano", "urticaceas", "quenopodiaceas"]
targets = [0, 1, 2]
for tipo in tipos_polinicos:
    df = pd.read_csv(f'../my_datasets/datos_{tipo}.csv')
    df["fecha"] = pd.to_datetime(df["fecha"])
    create_targets(df, tipo)
    df.to_csv(f'../my_datasets/datos_{tipo}.csv', index=False)

    for i in targets:
        FEATURES = json.load(open('json/allFeatures.json', 'r', encoding='utf-8'))
        TARGET = f'target_t{i}'

        train_data = df.dropna(subset=[TARGET]).copy()

        X_train = train_data[FEATURES]
        y_train = train_data[TARGET]

        y_train_log = np.log1p(y_train)

        if f"polen_{tipo}" in X_train.columns:
            X_train = X_train.drop(columns=[f"polen_{tipo}"])
        X_train = X_train.drop(columns=X_train.filter(regex=r'^target_t').columns)

        pesos = calculate_weights(y_train, X_train)
        X_train = apply_safety_noise(X_train, tipo, seed=42)

        with open(f"json/{tipo}/optuna_best_params_t{i}.json", "r") as f:
            best_params = json.load(f)

        prelim_reg = xgb.XGBRegressor(
            base_score=0.5, booster="gbtree", objective="reg:squarederror", **best_params
        )
        prelim_reg.fit(X_train, y_train_log)

        importancias = pd.DataFrame(
            {"feature": FEATURES, "importance": prelim_reg.feature_importances_}
        ).sort_values("importance", ascending=False)

        TOP_FEATURES = importancias[importancias["importance"] > 0.002]["feature"].tolist()

        if len(TOP_FEATURES) < 10:
            TOP_FEATURES = importancias.head(10)["feature"].tolist()

        X_train_clean = X_train[TOP_FEATURES]

        with open(f'json/{tipo}/features_t{i}.json', 'w') as f:
            json.dump(TOP_FEATURES, f)


        reg = xgb.XGBRegressor(
            base_score=0.5, booster="gbtree", objective="reg:squarederror", **best_params
        )

        reg.fit(
            X_train_clean,
            y_train_log,
            eval_set=[(X_train_clean, y_train_log)],
            verbose=100,
            sample_weight=pesos,
        )

        reg.get_booster().save_model(f"json/{tipo}/modelo_t{i}.json")
# Out:
# [0]	validation_0-rmse:1.49716
# [100]	validation_0-rmse:0.83571
# [200]	validation_0-rmse:0.56327
# [300]	validation_0-rmse:0.46140
# [400]	validation_0-rmse:0.41894
# [500]	validation_0-rmse:0.39472
# [600]	validation_0-rmse:0.37875
# [700]	validation_0-rmse:0.36867
# [800]	validation_0-rmse:0.36461
# [900]	validation_0-rmse:0.36384
# [1000]	validation_0-rmse:0.36332
# [1100]	validation_0-rmse:0.36271
# [1200]	validation_0-rmse:0.36204
# [1300]	validation_0-rmse:0.36184
# [1400]	validation_0-rmse:0.36151
# [1500]	validation_0-rmse:0.36120
# [1600]	validation_0-rmse:0.36079
# [1700]	validation_0-rmse:0.36051
# [1800]	validation_0-rmse:0.36016
# [1900]	validation_0-rmse:0.36005
# [1997]	validation_0-rmse:0.35982
# [0]	validation_0-rmse:1.39572
# [100]	validation_0-rmse:0.36290
# [200]	validation_0-rmse:0.36051
# [300]	validation_0-rmse:0.35874
# [400]	validation_0-rmse:0.35795
# [500]	validation_0-rmse:0.35767
# [600]	validation_0-rmse:0.35764
# [700]	validation_0-rmse:0.35741
# [800]	validation_0-rmse:0.35668
# [900]	validation_0-rmse:0.35646
# [1000]	validation_0-rmse:0.35625
# [1096]	validation_0-rmse:0.35558
# [0]	validation_0-rmse:1.48485
# [100]	validation_0-rmse:0.55787
# [200]	validation_0-rmse:0.45935
# [300]	validation_0-rmse:0.42858
# [400]	validation_0-rmse:0.41832
# [500]	validation_0-rmse:0.41515
# [600]	validation_0-rmse:0.41349
# [700]	validation_0-rmse:0.41176
# [800]	validation_0-rmse:0.41104
# [900]	validation_0-rmse:0.41030
# [1000]	validation_0-rmse:0.40981
# [1100]	validation_0-rmse:0.40958
# [1200]	validation_0-rmse:0.40932
# [1300]	validation_0-rmse:0.40885
# [1400]	validation_0-rmse:0.40825
# [1500]	validation_0-rmse:0.40801
# [1600]	validation_0-rmse:0.40727
# [1626]	validation_0-rmse:0.40717
# [0]	validation_0-rmse:2.02149
# [100]	validation_0-rmse:0.74207
# [200]	validation_0-rmse:0.64352
# [300]	validation_0-rmse:0.57451
# [400]	validation_0-rmse:0.54782
# [500]	validation_0-rmse:0.54161
# [600]	validation_0-rmse:0.53608
# [700]	validation_0-rmse:0.53174
# [800]	validation_0-rmse:0.52948
# [900]	validation_0-rmse:0.52664
# [1000]	validation_0-rmse:0.52357
# [1100]	validation_0-rmse:0.52327
# [1200]	validation_0-rmse:0.52264
# [1300]	validation_0-rmse:0.52202
# [1400]	validation_0-rmse:0.52066
# [1500]	validation_0-rmse:0.52048
# [1600]	validation_0-rmse:0.51972
# [1700]	validation_0-rmse:0.51935
# [1800]	validation_0-rmse:0.51793
# [1900]	validation_0-rmse:0.51786
# [1927]	validation_0-rmse:0.51791
# [0]	validation_0-rmse:2.00606
# [100]	validation_0-rmse:0.31325
# [200]	validation_0-rmse:0.31206
# [300]	validation_0-rmse:0.31096
# [400]	validation_0-rmse:0.31008
# [500]	validation_0-rmse:0.30979
# [600]	validation_0-rmse:0.30934
# [700]	validation_0-rmse:0.30876
# [800]	validation_0-rmse:0.30837
# [900]	validation_0-rmse:0.30808
# [1000]	validation_0-rmse:0.30775
# [1087]	validation_0-rmse:0.30781
# [0]	validation_0-rmse:2.03721
# [100]	validation_0-rmse:0.44447
# [200]	validation_0-rmse:0.43526
# [300]	validation_0-rmse:0.43481
# [400]	validation_0-rmse:0.43406
# [500]	validation_0-rmse:0.43271
# [600]	validation_0-rmse:0.43245
# [700]	validation_0-rmse:0.43217
# [800]	validation_0-rmse:0.43215
# [815]	validation_0-rmse:0.43214
# [0]	validation_0-rmse:1.20328
# [100]	validation_0-rmse:0.38214
# [200]	validation_0-rmse:0.31940
# [300]	validation_0-rmse:0.27820
# [400]	validation_0-rmse:0.24569
# [500]	validation_0-rmse:0.23028
# [600]	validation_0-rmse:0.22591
# [700]	validation_0-rmse:0.22246
# [800]	validation_0-rmse:0.21810
# [900]	validation_0-rmse:0.21699
# [1000]	validation_0-rmse:0.21394
# [1100]	validation_0-rmse:0.21243
# [1200]	validation_0-rmse:0.21118
# [1300]	validation_0-rmse:0.20983
# [1400]	validation_0-rmse:0.20897
# [1500]	validation_0-rmse:0.20858
# [1600]	validation_0-rmse:0.20798
# [1700]	validation_0-rmse:0.20593
# [1732]	validation_0-rmse:0.20593
# [0]	validation_0-rmse:1.27923
# [100]	validation_0-rmse:0.40379
# [200]	validation_0-rmse:0.34015
# [300]	validation_0-rmse:0.29925
# [400]	validation_0-rmse:0.28296
# [500]	validation_0-rmse:0.27730
# [600]	validation_0-rmse:0.27431
# [700]	validation_0-rmse:0.27267
# [706]	validation_0-rmse:0.27265
# [0]	validation_0-rmse:1.28982
# [100]	validation_0-rmse:0.31578
# [200]	validation_0-rmse:0.24541
# [300]	validation_0-rmse:0.23439
# [400]	validation_0-rmse:0.23339
# [500]	validation_0-rmse:0.23267
# [600]	validation_0-rmse:0.23204
# [700]	validation_0-rmse:0.23114
# [800]	validation_0-rmse:0.23096
# [900]	validation_0-rmse:0.23047
# [1000]	validation_0-rmse:0.23033
# [1100]	validation_0-rmse:0.23024
# [1200]	validation_0-rmse:0.23004
# [1300]	validation_0-rmse:0.22974
# [1400]	validation_0-rmse:0.22975
# [1411]	validation_0-rmse:0.22984
# [0]	validation_0-rmse:1.74368
# [100]	validation_0-rmse:0.39077
# [200]	validation_0-rmse:0.35553
# [300]	validation_0-rmse:0.33479
# [400]	validation_0-rmse:0.32396
# [500]	validation_0-rmse:0.32024
# [510]	validation_0-rmse:0.32015
# [0]	validation_0-rmse:1.71912
# [100]	validation_0-rmse:0.26919
# [200]	validation_0-rmse:0.26753
# [300]	validation_0-rmse:0.26732
# [400]	validation_0-rmse:0.26647
# [500]	validation_0-rmse:0.26589
# [600]	validation_0-rmse:0.26568
# [700]	validation_0-rmse:0.26525
# [777]	validation_0-rmse:0.26504
# [0]	validation_0-rmse:1.73181
# [100]	validation_0-rmse:0.40052
# [200]	validation_0-rmse:0.37059
# [300]	validation_0-rmse:0.36518
# [400]	validation_0-rmse:0.36173
# [500]	validation_0-rmse:0.36100
# [600]	validation_0-rmse:0.36064
# [700]	validation_0-rmse:0.35977
# [800]	validation_0-rmse:0.35946
# [900]	validation_0-rmse:0.35878
# [1000]	validation_0-rmse:0.35878
# [1100]	validation_0-rmse:0.35871
# [1200]	validation_0-rmse:0.35837
# [1255]	validation_0-rmse:0.35793
# [0]	validation_0-rmse:1.06392
# [100]	validation_0-rmse:0.72074
# [200]	validation_0-rmse:0.62841
# [300]	validation_0-rmse:0.60478
# [400]	validation_0-rmse:0.59349
# [500]	validation_0-rmse:0.58362
# [600]	validation_0-rmse:0.57434
# [700]	validation_0-rmse:0.56501
# [800]	validation_0-rmse:0.55721
# [900]	validation_0-rmse:0.54988
# [1000]	validation_0-rmse:0.54248
# [1100]	validation_0-rmse:0.53548
# [1200]	validation_0-rmse:0.52910
# [1300]	validation_0-rmse:0.52324
# [1400]	validation_0-rmse:0.51749
# [1500]	validation_0-rmse:0.51167
# [1600]	validation_0-rmse:0.50582
# [1700]	validation_0-rmse:0.50054
# [1738]	validation_0-rmse:0.49842
# [0]	validation_0-rmse:1.06281
# [100]	validation_0-rmse:0.68499
# [200]	validation_0-rmse:0.59671
# [300]	validation_0-rmse:0.56773
# [400]	validation_0-rmse:0.54915
# [500]	validation_0-rmse:0.53207
# [600]	validation_0-rmse:0.51815
# [700]	validation_0-rmse:0.50415
# [800]	validation_0-rmse:0.49148
# [900]	validation_0-rmse:0.48052
# [1000]	validation_0-rmse:0.46954
# [1100]	validation_0-rmse:0.45912
# [1200]	validation_0-rmse:0.44904
# [1300]	validation_0-rmse:0.43900
# [1400]	validation_0-rmse:0.42978
# [1500]	validation_0-rmse:0.42043
# [1600]	validation_0-rmse:0.41196
# [1700]	validation_0-rmse:0.40361
# [1800]	validation_0-rmse:0.39507
# [1900]	validation_0-rmse:0.38732
# [1960]	validation_0-rmse:0.38273
# [0]	validation_0-rmse:1.06180
# [100]	validation_0-rmse:0.65917
# [200]	validation_0-rmse:0.58288
# [300]	validation_0-rmse:0.55284
# [400]	validation_0-rmse:0.52974
# [500]	validation_0-rmse:0.51206
# [600]	validation_0-rmse:0.49643
# [700]	validation_0-rmse:0.48245
# [800]	validation_0-rmse:0.46987
# [900]	validation_0-rmse:0.45788
# [1000]	validation_0-rmse:0.44535
# [1100]	validation_0-rmse:0.43486
# [1144]	validation_0-rmse:0.43040
# [0]	validation_0-rmse:0.71674
# [100]	validation_0-rmse:0.52802
# [200]	validation_0-rmse:0.43805
# [300]	validation_0-rmse:0.39308
# [400]	validation_0-rmse:0.36786
# [500]	validation_0-rmse:0.34926
# [600]	validation_0-rmse:0.33358
# [700]	validation_0-rmse:0.31990
# [800]	validation_0-rmse:0.30752
# [900]	validation_0-rmse:0.29688
# [1000]	validation_0-rmse:0.28715
# [1100]	validation_0-rmse:0.27762
# [1200]	validation_0-rmse:0.26895
# [1300]	validation_0-rmse:0.26053
# [1400]	validation_0-rmse:0.25239
# [1500]	validation_0-rmse:0.24536
# [1600]	validation_0-rmse:0.23860
# [1700]	validation_0-rmse:0.23330
# [1800]	validation_0-rmse:0.22927
# [1830]	validation_0-rmse:0.22822
# [0]	validation_0-rmse:0.70782
# [100]	validation_0-rmse:0.35525
# [200]	validation_0-rmse:0.29100
# [300]	validation_0-rmse:0.25488
# [400]	validation_0-rmse:0.22433
# [500]	validation_0-rmse:0.20129
# [600]	validation_0-rmse:0.17850
# [700]	validation_0-rmse:0.16111
# [800]	validation_0-rmse:0.14491
# [851]	validation_0-rmse:0.13830
# [0]	validation_0-rmse:0.70646
# [100]	validation_0-rmse:0.35246
# [200]	validation_0-rmse:0.32307
# [300]	validation_0-rmse:0.32102
# [400]	validation_0-rmse:0.31964
# [500]	validation_0-rmse:0.31920
# [600]	validation_0-rmse:0.31924
# [700]	validation_0-rmse:0.31873
# [800]	validation_0-rmse:0.31849
# [900]	validation_0-rmse:0.31835
# [1000]	validation_0-rmse:0.31834
# [1100]	validation_0-rmse:0.31816
# [1200]	validation_0-rmse:0.31838
# [1300]	validation_0-rmse:0.31822
# [1400]	validation_0-rmse:0.31792
# [1483]	validation_0-rmse:0.31792

# %% [markdown]
# ### Test Models (Temporal Cross Validation)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from matplotlib.lines import Line2D

tipos_polinicos = {
    "gramineas": (400, 10, 50),
    "cupresaceas": (500, 50, 150),
    "olivo": (500, 50, 200),
    "platano": (300, 50, 150),
    "urticaceas": (100, 10, 40),
    "quenopodiaceas": (30, 5, 10)
}

def test_model(tipo, target, anos_validacion):
    resultados_mae = []

    df = pd.read_csv(f'../my_datasets/datos_{tipo}.csv')
    df["fecha"] = pd.to_datetime(df["fecha"])
    create_targets(df, tipo)

    for v_year in anos_validacion:
        print(f"\n--- Evaluando Fold: Entrenando con años < {v_year} | Validando con {v_year} ---")
        TARGET = f'target_t{target}'
        FEATURES = json.load(open('json/allFeatures.json', 'r', encoding='utf-8'))
        
        train_data = df[df['fecha'].dt.year < v_year].copy().dropna(subset=[TARGET])
        test_data = df[df['fecha'].dt.year == v_year].copy().dropna(subset=[TARGET])

        X_train = train_data[FEATURES]
        X_val = test_data[FEATURES]

        columnas_leakage = [c for c in X_train.columns if c.startswith('target_t') or c == f"polen_{tipo}"]

        X_train = X_train.drop(columns=columnas_leakage, errors='ignore')
        X_val = X_val.drop(columns=columnas_leakage, errors='ignore')
        
        y_train = train_data[TARGET]
        y_val = test_data[TARGET]

        pesos = calculate_weights(y_train, X_train)
        X_train = apply_safety_noise(X_train, tipo, seed=42)

        y_train_log = np.log1p(y_train)
        
        # Entrenar modelo
        with open(f"json/{tipo}/optuna_best_params_t{target}.json", "r") as f:
            best_params = json.load(f)
        reg = xgb.XGBRegressor(**best_params)
        reg.fit(X_train, y_train_log, sample_weight=pesos)
        
        # Reversión logaritmos
        preds_log = reg.predict(X_val)
        preds_reales = np.expm1(preds_log)
        y_val_reales = y_val
        
        mae_fold = mean_absolute_error(y_val_reales, preds_reales)
        resultados_mae.append(mae_fold)
        print(f"MAE para el año {v_year}: {mae_fold:.2f} granos")

        test_data = pd.read_csv(f'../my_datasets/datos_{tipo}.csv')
        targetCol = f'target_t{target}'

        #Make predictions
        test_data["fecha"] = pd.to_datetime(test_data["fecha"])
        test_data = test_data[test_data["fecha"].dt.year == v_year].dropna(subset=[targetCol]).copy()

        with open(f'json/{tipo}/features_t{target}.json', 'r') as f:
            TOP_FEATURES = json.load(f)

        reg = xgb.XGBRegressor()
        reg.load_model(f'json/{tipo}/modelo_t{target}.json')

        preds_log = reg.predict(test_data[TOP_FEATURES])
        preds_reales = np.expm1(preds_log)
        test_data[f"prediccion_t{target}"] = preds_reales

        
        #--- VISUALIZACIÓN ---

        test_data_temporada = test_data.copy()

        def obtener_zona(valor):
            if valor < tipos_polinicos[tipo][1]:
                return 0
            elif tipos_polinicos[tipo][1] <= valor <= tipos_polinicos[tipo][2]:
                return 1
            else:
                return 2
            
        test_data_temporada["zona_real"] = test_data_temporada[targetCol].apply(obtener_zona)
        test_data_temporada["zona_pred"] = test_data_temporada[f"prediccion_t{target}"].apply(obtener_zona)

        test_data_temporada["color_punto"] = np.where(
            test_data_temporada["zona_real"] != test_data_temporada["zona_pred"], "red", "blue"
        )

        test_data_temporada["target_visual"] = test_data_temporada[targetCol].clip(upper=tipos_polinicos[tipo][0])
        test_data_temporada["pred_visual"] = test_data_temporada[f"prediccion_t{target}"].clip(upper=tipos_polinicos[tipo][0])

        plt.figure(figsize=(15, 8))
        plt.axhspan(0, tipos_polinicos[tipo][1], color="green", alpha=0.15, label="Bajo (< {tipos_polinicos[tipo][1]})")
        plt.axhspan(tipos_polinicos[tipo][1], tipos_polinicos[tipo][2], color="yellow", alpha=0.15, label="Moderado ({tipos_polinicos[tipo][1]}-{tipos_polinicos[tipo][2]})")
        plt.axhspan(tipos_polinicos[tipo][2], tipos_polinicos[tipo][0], color="red", alpha=0.15, label="Alto (> {tipos_polinicos[tipo][2]})")

        plt.plot(
            test_data_temporada["fecha"],
            test_data_temporada["target_visual"],
            label=f"Real ({tipo})",
            color="blue",
            alpha=0.4,
            linewidth=1,
        )
        plt.plot(
            test_data_temporada["fecha"],
            test_data_temporada["pred_visual"],
            label="Predicción Modelo",
            color="gray",
            linestyle="--",
            alpha=0.4,
            linewidth=1,
        )

        plt.scatter(
            test_data_temporada["fecha"],
            test_data_temporada["pred_visual"],
            c=test_data_temporada["color_punto"],
            s=40,
            zorder=5,
            edgecolor="black",
            linewidth=0.5,
        )

        plt.ylim(0, tipos_polinicos[tipo][0] + 10)
        plt.ylabel("Granos de polen / $m^3$ (Topado a 300)")

        plt.title("Comparativa de Polen: " + tipo.capitalize())
        plt.xlabel("Fecha")
        plt.ylabel("Granos de polen / $m^3$")

        legend_elements = [
            Line2D([0], [0], color="blue", lw=2, label="Dato Real"),
            Line2D([0], [0], color="gray", linestyle="--", label="Tendencia Predicción"),
            Line2D(
                [0],
                [0],
                marker="o",
                color="w",
                label="Predicción (Zona Correcta)",
                markerfacecolor="blue",
                markersize=8,
            ),
            Line2D(
                [0],
                [0],
                marker="o",
                color="w",
                label="Predicción (Zona Incorrecta)",
                markerfacecolor="red",
                markersize=8,
            ),
            plt.Rectangle((0, 0), 1, 1, fc="green", alpha=0.15, label="Zona Verde ($<50$)"),
            plt.Rectangle(
                (0, 0), 1, 1, fc="yellow", alpha=0.15, label="Zona Amarilla ($50-150$)"
            ),
            plt.Rectangle((0, 0), 1, 1, fc="red", alpha=0.15, label="Zona Roja ($>150$)"),
        ]
        plt.legend(handles=legend_elements, loc="upper left", bbox_to_anchor=(1, 1))

        plt.grid(True, linestyle=":", alpha=0.6)
        plt.tight_layout()
        os.makedirs('output', exist_ok=True)
        plt.savefig(rf'output/{tipo}_pred_t+{target}.png', dpi=300, bbox_inches='tight') # Guardar
        plt.show()

        fi = pd.DataFrame(
            data=reg.feature_importances_, index=reg.feature_names_in_, columns=["importance"]
        )
        fi.sort_values("importance", ascending=False).head(25).sort_values("importance").plot(
            kind="barh", title="Top 25 Feature Importance"
        )
        plt.show()

        mae = mean_absolute_error(
            test_data_temporada[targetCol], test_data_temporada[f"prediccion_t{target}"]
        )
        r2 = r2_score(test_data_temporada[targetCol], test_data_temporada[f"prediccion_t{target}"])

        print(f"Error Medio Absoluto (MAE): {mae:.2f} granos")
        print(f"Coeficiente de determinación ($R^2$): {r2:.2f}")
        
    print(f"\n=== MAE Promedio de la Validación Cruzada: {np.mean(resultados_mae):.2f} granos ===")

# %%
tipos_polinicos = {
    "gramineas": (400, 10, 50),
    "cupresaceas": (500, 50, 150),
    "olivo": (500, 50, 200),
    "platano": (300, 50, 150),
    "urticaceas": (100, 10, 40),
    "quenopodiaceas": (30, 5, 10)
}
test_model('gramineas', target = 2, anos_validacion = [2023, 2024, 2025])
# Out:
# --- Evaluando Fold: Entrenando con años < 2023 | Validando con 2023 ---
# MAE para el año 2023: 1.93 granos
# Error Medio Absoluto (MAE): 1.08 granos
# Coeficiente de determinación ($R^2$): 0.81
#
# --- Evaluando Fold: Entrenando con años < 2024 | Validando con 2024 ---
# MAE para el año 2024: 5.20 granos
# Error Medio Absoluto (MAE): 2.44 granos
# Coeficiente de determinación ($R^2$): 0.94
#
# --- Evaluando Fold: Entrenando con años < 2025 | Validando con 2025 ---
# MAE para el año 2025: 9.93 granos
# Error Medio Absoluto (MAE): 3.21 granos
# Coeficiente de determinación ($R^2$): 0.96
#
# === MAE Promedio de la Validación Cruzada: 5.69 granos ===
