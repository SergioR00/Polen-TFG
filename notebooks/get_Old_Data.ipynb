# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# %% [markdown]
# ### Getting the data

# %%
# Contaminantes
contaminantes2025_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2025.csv", sep=';')
contaminantes2024_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2024.csv", sep=';')
contaminantes2023_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2023.csv", sep=';')
contaminantes2022_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2022.csv", sep=';')
contaminantes2021_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2021.csv", sep=';')
contaminantes2020_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2020.csv", sep=';')
contaminantes2019_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2019.csv", sep=';')
contaminantes2018_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2018.csv", sep=';')
contaminantes2017_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2017.csv", sep=';')
contaminantes2016_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2016.csv", sep=';')
contaminantes2015_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2015.csv", sep=';')
contaminantes2014_df = pd.read_csv(r"..\original_datasets/CONTAMINANTES_2014.csv", sep=';')

# Polen
polen2025Full_df = pd.read_csv(r"..\original_datasets/polen_2025.csv", encoding='latin1', sep=';')
polen2025_df = polen2025Full_df[polen2025Full_df['captador'] == 'AYTM']
polen2025_df['fecha'] = pd.to_datetime(polen2025_df['fecha_lectura']).dt.date
polen2025_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2024Full_df = pd.read_csv(r"..\original_datasets/polen_2024.csv", encoding='latin1', sep=';')
polen2024_df = polen2024Full_df[polen2024Full_df['captador'] == 'AYTM']
polen2024_df['fecha'] = pd.to_datetime(polen2024_df['fecha_lectura']).dt.date
polen2024_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2023Full_df = pd.read_csv(r"..\original_datasets/polen_2023.csv", encoding='latin1', sep=';')
polen2023_df = polen2023Full_df[polen2023Full_df['captador'] == 'AYTM']
polen2023_df['fecha'] = pd.to_datetime(polen2023_df['fecha_lectura']).dt.date
polen2023_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2022Full_df = pd.read_csv(r"..\original_datasets/polen_2022.csv", encoding='latin1', sep=';')
polen2022_df = polen2022Full_df[polen2022Full_df['captador'] == 'AYTM']
polen2022_df['fecha'] = pd.to_datetime(polen2022_df['fecha_lectura']).dt.date
polen2022_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2021Full_df = pd.read_csv(r"..\original_datasets/polen_2021.csv", encoding='latin1', sep=';')
polen2021_df = polen2021Full_df[polen2021Full_df['captador'] == 'AYTM']
polen2021_df['fecha'] = pd.to_datetime(polen2021_df['fecha_lectura']).dt.date
polen2021_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2020Full_df = pd.read_csv(r"..\original_datasets/polen_2020.csv", encoding='latin1', sep=';')
polen2020_df = polen2020Full_df[polen2020Full_df['captador'] == 'AYTM']
polen2020_df['fecha'] = pd.to_datetime(polen2020_df['fecha_lectura']).dt.date
polen2020_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2019Full_df = pd.read_csv(r"..\original_datasets/polen_2019.csv", encoding='latin1', sep=';')
polen2019_df = polen2019Full_df[polen2019Full_df['captador'] == 'AYTM']
polen2019_df['fecha'] = pd.to_datetime(polen2019_df['fecha_lectura']).dt.date
polen2019_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2018Full_df = pd.read_csv(r"..\original_datasets/polen_2018.csv", encoding='latin1', sep=';')
polen2018_df = polen2018Full_df[polen2018Full_df['captador'] == 'AYTM']
polen2018_df['fecha'] = pd.to_datetime(polen2018_df['fecha_lectura']).dt.date
polen2018_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2017Full_df = pd.read_csv(r"..\original_datasets/polen_2017.csv", encoding='latin1', sep=';')
polen2017_df = polen2017Full_df[polen2017Full_df['captador'] == 'AYTM']
polen2017_df['fecha'] = pd.to_datetime(polen2017_df['fecha_lectura']).dt.date
polen2017_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2016Full_df = pd.read_csv(r"..\original_datasets/polen_2016.csv", encoding='latin1', sep=';')
polen2016_df = polen2016Full_df[polen2016Full_df['captador'] == 'AYTM']
polen2016_df['fecha'] = pd.to_datetime(polen2016_df['fecha_lectura']).dt.date
polen2016_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2015Full_df = pd.read_csv(r"..\original_datasets/polen_2015.csv", encoding='latin1', sep=';')
polen2015_df = polen2015Full_df[polen2015Full_df['captador'] == 'AYTM']
polen2015_df['fecha'] = pd.to_datetime(polen2015_df['fecha_lectura']).dt.date
polen2015_df.drop(columns=['fecha_lectura','captador'], inplace=True)

polen2014Full_df = pd.read_csv(r"..\original_datasets/polen_2014.csv", encoding='latin1', sep=';')
polen2014_df = polen2014Full_df[polen2014Full_df['captador'] == 'AYTM']
polen2014_df['fecha'] = pd.to_datetime(polen2014_df['fecha_lectura']).dt.date
polen2014_df.drop(columns=['fecha_lectura','captador'], inplace=True)

# Condiciones ambientales
OPENMETEO2025_df = pd.read_csv(r"..\original_datasets/open-meteo-2025.csv")
OPENMETEO2024_df = pd.read_csv(r"..\original_datasets/open-meteo-2024.csv")
OPENMETEO2023_df = pd.read_csv(r"..\original_datasets/open-meteo-2023.csv")
OPENMETEO2022_df = pd.read_csv(r"..\original_datasets/open-meteo-2022.csv")
OPENMETEO2021_df = pd.read_csv(r"..\original_datasets/open-meteo-2021.csv")
OPENMETEO2020_df = pd.read_csv(r"..\original_datasets/open-meteo-2020.csv")
OPENMETEO2019_df = pd.read_csv(r"..\original_datasets/open-meteo-2019.csv")
OPENMETEO2018_df = pd.read_csv(r"..\original_datasets/open-meteo-2018.csv")
OPENMETEO2017_df = pd.read_csv(r"..\original_datasets/open-meteo-2017.csv")
OPENMETEO2016_df = pd.read_csv(r"..\original_datasets/open-meteo-2016.csv")
OPENMETEO2015_df = pd.read_csv(r"..\original_datasets/open-meteo-2015.csv")
OPENMETEO2014_df = pd.read_csv(r"..\original_datasets/open-meteo-2014.csv")

polen2025_df
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_12984\4224350147.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polen2025_df['fecha'] = pd.to_datetime(polen2025_df['fecha_lectura']).dt.date
# C:\Users\sergi\AppData\Local\Temp\ipykernel_12984\4224350147.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polen2025_df.drop(columns=['fecha_lectura','captador'], inplace=True)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_12984\4224350147.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Parsing Contaminantes

# %%
años = range(2014, 2026)
lista_dfs = [globals()[f"contaminantes{año}_df"] for año in años]
df_contaminantes_total = pd.concat(lista_dfs, ignore_index=True)

df_contaminantes_total = df_contaminantes_total[(df_contaminantes_total['MUNICIPIO'] == 79) & 
                 (df_contaminantes_total['ESTACION'] == 8)].copy()

magnitude_map = {
    1: 'SO2 (ug/m3)', 6: 'CO (mg/m3)', 7: 'NO (ug/m3)', 8: 'NO2 (ug/m3)',
    9: 'PM2.5 (ug/m3)', 10: 'PM10 (ug/m3)', 12: 'NOx (ug/m3)', 14: 'O3 (ug/m3)',
    20: 'Tolueno (ug/m3)', 30: 'Benceno (ug/m3)', 42: 'HCT (mg/m3)', 44: 'HCNM (mg/m3)'
}

# 4. Reestructurar el dataset de horizontal a vertical
d_cols = [f'D{i:02d}' for i in range(1, 32)]
v_cols = [f'V{i:02d}' for i in range(1, 32)]

rows = []
for idx, row in df_contaminantes_total.iterrows():
    for d, v in zip(d_cols, v_cols):
        day_num = int(d[1:])
        # Limpiar valor y verificar si es válido ('V')
        if row[v] == 'V':
            val = str(row[d]).replace(',', '.')
            rows.append({
                'ano': row['ANO'], 'mes': row['MES'], 'dia': day_num,
                'magnitud': row['MAGNITUD'],
                'valor': pd.to_numeric(val, errors='coerce')
            })

df_melted = pd.DataFrame(rows)

# 5. Crear la columna de fecha y limpiar errores (ej. 31 de febrero)
df_melted['fecha'] = pd.to_datetime(df_melted[['ano', 'mes', 'dia']].rename(
    columns={'ano': 'year', 'mes': 'month', 'dia': 'day'}), errors='coerce')
df_melted = df_melted.dropna(subset=['fecha'])

# 6. Pivotar: Magnitudes a columnas
df_melted['magnitud_nombre'] = df_melted['magnitud'].map(magnitude_map)
df_final_contaminantes = df_melted.pivot_table(index='fecha', columns='magnitud_nombre', values='valor')

df_final_contaminantes = df_final_contaminantes.reset_index()
df_final_contaminantes = df_final_contaminantes.sort_values('fecha')

df_final_contaminantes = df_final_contaminantes.drop(columns=["HCNM (mg/m3)", "HCT (mg/m3)"])

df_final_contaminantes.to_csv(r"..\new_datasets/contaminantes_2021_2025.csv", index=False, encoding='utf-8')

# %% [markdown]
# ### Parsing Polen (solo gramineas)

# %%
años = range(2014, 2026)

lista_dfs = []
for año in años:
    df = globals()[f"polen{año}_df"]
    
    filtro = df[df['tipo_polinico'].str.contains('Gram.neas', na=False)]

    filtro = filtro.copy()
    filtro['año'] = año
    
    lista_dfs.append(filtro)
df_gramineas_total = pd.concat(lista_dfs, ignore_index=True)
df_gramineas_total = df_gramineas_total.drop(columns=["tipo_polinico", "año"])

df_gramineas_total.to_csv(r"..\new_datasets/gramineas_2014_2025.csv", index=False, encoding='utf-8')

# %% [markdown]
# ### Parsing OPEN-METEO

# %%
años = range(2014, 2026)
lista_dfs = [globals()[f"OPENMETEO{año}_df"] for año in años]
df_meteo_total = pd.concat(lista_dfs, ignore_index=True)

df_meteo_total['fecha'] = pd.to_datetime(df_meteo_total['time']).dt.date
df_meteo_total2 = df_meteo_total.groupby('fecha').mean(numeric_only=True).reset_index()

df_meteo_total2.to_csv(r"..\new_datasets/meteo_2021_2025.csv", index=False, encoding='utf-8')

# %% [markdown]
# ### Mixing (polen + contaminantes + meteo)

# %%
df_gramineas_total['fecha'] = pd.to_datetime(df_gramineas_total['fecha']).dt.normalize()
df_meteo_total2['fecha'] = pd.to_datetime(df_meteo_total2['fecha']).dt.normalize()
df_final_contaminantes['fecha'] = pd.to_datetime(df_final_contaminantes['fecha']).dt.normalize()

df_WMeteo = pd.merge(df_gramineas_total, df_meteo_total2, on='fecha', how='outer')
df_WMeteo_WContaminantes = pd.merge(df_WMeteo, df_final_contaminantes, on='fecha', how='outer')
df_WMeteo_WContaminantes = df_WMeteo_WContaminantes.sort_values('fecha')

df_WMeteo_WContaminantes.to_csv(r"..\new_datasets\datos_gramineas.csv", index=False)
